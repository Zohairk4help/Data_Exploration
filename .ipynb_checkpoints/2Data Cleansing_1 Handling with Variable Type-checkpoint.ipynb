# %% [raw]
# ---> Determine the types of the below-given variables:
# Age
# Salary
# Income
# Customer type
# Stock price

# %%
print("Age is ratio variable data type which falls under the category of the Continuous numerical Data.")
print("Salary is continuous data type which falls under the category of the Numerical/Float Data.")
print("Income is continuous data type which falls under the category of the Numerical/Float Data.")
print("Customer Type is Nominal data type which falls under the category of the Categotical Data.")
print("Stock Price is continuous data type which falls under the category of the Numerical/Float Data.")
# Out:
# Age is ratio variable data type which falls under the category of the Continuous numerical Data.
# Salary is continuous data type which falls under the category of the Numerical/Float Data.
# Income is continuous data type which falls under the category of the Numerical/Float Data.
# Customer Type is Nominal data type which falls under the category of the Categotical Data.
# Stock Price is continuous data type which falls under the category of the Numerical/Float Data.

# %% [raw]
# ----> Using the movie data,
# 1)Select a continuous and a categorical variable from the movie dataset and discuss the variable type of this variable. Discuss further in detail the type of selected continuous and categorical variables.
# 2)Categorize a variable of your choice and assign a name to it
# 3) Count the number of rows for each category

# %%
import pandas as pd

data = pd.read_csv("movies.csv")
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.columns.array
# Out:
# <PandasArray>
# [              'Rank',              'Title',              'Genre',
#         'Description',           'Director',             'Actors',
#                'Year',  'Runtime (Minutes)',             'Rating',
#               'Votes', 'Revenue (Millions)',          'Metascore']
# Length: 12, dtype: object

# %% [markdown]
# ##### There are 12 columns as shown above in cell 1 and 2 and there are 1000 rows for each columns as shown in cell 1

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline 

import seaborn as sns

from scipy import stats

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
data.describe(include=['O'])
# Out:
#            Title                    Genre  \
# count       1000                     1000
# unique       999                      207
# top     The Host  Action,Adventure,Sci-Fi
# freq           2                       50
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     After he reconnects with an awkward pal from h...  Ridley Scott
# freq                                                    1             8
#
#                                                    Actors
# count                                                1000
# unique                                                996
# top     Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese ...
# freq                                                    2

# %% [markdown]
# ##### using the two kind of data.describe and data.describe(include=['0']), it was found by latter code the columns that are categorical and the former one showed columns in numeric data types.

# %%
data['Rating'].describe()
# Out:
# count    1000.000000
# mean        6.723200
# std         0.945429
# min         1.900000
# 25%         6.200000
# 50%         6.800000
# 75%         7.400000
# max         9.000000
# Name: Rating, dtype: float64

# %%
print(data['Year'].unique())
print(data['Director'].unique())
print(data['Genre'].unique())
print("Rating", data['Rating'].unique())
print("votessssssssssss", data['Votes'].unique())
print("Revenue (Millions)", data['Revenue (Millions)'].unique())
print("Metascoressssssssssss", data['Metascore'].unique())
# Out:
# [2014 2012 2016 2015 2007 2011 2008 2006 2009 2010 2013]
# ['James Gunn' 'Ridley Scott' 'M. Night Shyamalan' 'Christophe Lourdelet'
#  'David Ayer' 'Yimou Zhang' 'Damien Chazelle' 'Sean Foley' 'James Gray'
#  'Morten Tyldum' 'David Yates' 'Theodore Melfi' 'Gareth Edwards'
#  'Ron Clements' 'Nacho Vigalondo' 'Chris Renaud' 'Mel Gibson'
#  'Paul Greengrass' 'Garth Davis' 'Denis Villeneuve' 'Stephen Gaghan'
#  'Kenneth Lonergan' 'Ben Young' 'Walt Dohrn' 'Roland Emmerich'
#  'Dominique Abel' 'S.S. Rajamouli' 'Phillip Guzman' 'Jon Lucas'
#  'Justin Kurzel' 'John Hamburg' 'Tom Ford' 'Bryan Singer' 'Tim Miller'
#  'Paul W.S. Anderson' 'Anthony Russo' 'Christopher Nolan'
#  'Scott Derrickson' 'Antoine Fuqua' 'Patrick Read Johnson' 'Greg Tiernan'
#  'Barry Jenkins' 'Shawn Burkett' 'John Lee Hancock' 'Ricardo de Montreuil'
#  'Rob Marshall' 'John Madden' 'Scott Hicks' 'Justin Lin' 'Sean Penn'
#  'J.J. Abrams' 'Anna Foerster' 'Garry Marshall' 'Chad Stahelski'
# ...

# %%
data.nunique().head(20)
# Out:
# Rank                  1000
# Title                  999
# Genre                  207
# Description           1000
# Director               644
# Actors                 996
# Year                    11
# Runtime (Minutes)       94
# Rating                  55
# Votes                  997
# Revenue (Millions)     814
# Metascore               84
# dtype: int64

# %%
def discretization(Rating):
    if Rating <= 2:
        return("1-2")
    elif (Rating > 2) and (Rating < 4):
        return("2-4")
    elif (Rating > 4) and (Rating < 6):
        return("4-6")
    elif (Rating > 6) and (Rating < 8):
        return("6-8")
    else:
        return("x>8")
data['Rating_range'] = data['Rating'].apply(discretization)
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
##### There are 13 columns as shown above in cell 11 and 1000 rows

# %%
data.groupby("Rating_range")["Rating"].count().sort_values(ascending=False)
# Out:
# Rating_range
# 6-8    712
# 4-6    172
# x>8    105
# 2-4     10
# 1-2      1
# Name: Rating, dtype: int64

# %%
data['Year'].describe()
# Out:
# count    1000.000000
# mean     2012.783000
# std         3.205962
# min      2006.000000
# 25%      2010.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2016.000000
# Name: Year, dtype: float64

# %%
def discretization(Year):
    if Year <= 2006:
        return("X < 2006")
    elif (Year >= 2006) and (Year <= 2008):
        return("2006-2008")
    elif (Year >= 2008) and (Year <= 2010):
        return("2008-2010")
    elif (Year >= 2010) and (Year <= 2012):
        return("2010-2012")
    elif (Year >= 2012) and (Year <= 2014):
        return("2012-2014")
    else:
        return("x > 2014")
data['Year_Range'] = data['Year'].apply(discretization)
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
##### There are 14 columns as shown above in cell 15

# %%
data.groupby("Year_Range")["Year"].count().sort_values(ascending=False)
# Out:
# Year_Range
# x > 2014     424
# 2012-2014    189
# 2010-2012    127
# 2008-2010    111
# 2006-2008    105
# X < 2006      44
# Name: Year, dtype: int64

# %%
data.groupby("Year_Range")["Year"].count().sort_values(ascending=False)
# Out:
# Year_Range
# x > 2014     424
# 2012-2014    189
# 2010-2012    127
# 2008-2010    111
# 2006-2008    105
# X < 2006      44
# Name: Year, dtype: int64

# %% [markdown]
# ###### By the example above, it is clearly seen that the column 'Year' from the dataframe, Data, becomes categorical even though it was continuos/numeric before.

# %% [markdown]
# ###### It is true that while continuous data is generally preferred over discrete data, discrete is the preferred data type although continuous data is available for the same characteristic. It is because as it is seen in the example above for the column "year", we can easily divide the highest ratings of the movies in the exact year.

# %% [markdown]
# ###### While continuous data is measured and attribute data is counted, there is sometimes confusion if some specific dataset should be considered continuous or attribute. The examples from the dataset, movies,csv are:
# ---> column 'Year'
# ---> column 'Metascore

# %%
data.hist(column='Year')
data.hist(column='Rating')
# Out:
# array([[<AxesSubplot:title={'center':'Rating'}>]], dtype=object)
